# %%
# !git clone https://github.com/UwU-tao/NARM.git
# Out:
# Cloning into 'NARM'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 36 (delta 9), reused 14 (delta 7), pack-reused 16
# Receiving objects: 100% (36/36), 36.44 KiB | 4.55 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# %cd /kaggle/working/NARM/datasets
# Out:
# /kaggle/working/NARM/datasets

# %%
# !python preprocess.py --dataset yoochoose \
--raw_path '/kaggle/input/recsys-challenge-2015/yoochoose-clicks.dat' \
--data_path '/kaggle/working/NARM/datasets/yoochoose-clicks-headers.dat'
# Out:
# -- Starting @ 2023-11-03 03:41:52.632054s
# 33003944it [06:57, 79121.47it/s]
# -- Reading data @ 2023-11-03 03:48:49.770345s
# Splitting date 1411959599.0
# 7966257
# 15324
# [('171168', 1396321232.0), ('345618', 1396321275.0), ('263073', 1396321302.0)]
# [('11532683', 1411959653.0), ('11464959', 1411959671.0), ('11296119', 1411959695.0)]
# -- Splitting train set and test set @ 2023-11-03 03:49:55.641787s
# 37484
# 23670982
# 55898
# [[1], [3], [5, 5]] [1396321232.0, 1396321275.0, 1396321302.0] [2, 4, 5]
# [[33611, 37169, 6409], [33611, 37169], [33611]] [1411959653.0, 1411959653.0, 1411959653.0] [33128, 6409, 37169]
# avg length:  3.9727042800167034
# 5917745
# 369859
# Done.

# %%
# %cd ..
# Out:
# /kaggle/working/Neural-Attentive-Session-Based-Recommendation-PyTorch

# %%
# !python main.py --dataset_path /kaggle/working/NARM/datasets/yoochoose1_64/
# Out:
# Namespace(dataset_path='/kaggle/working/Neural-Attentive-Session-Based-Recommendation-PyTorch/datasets/yoochoose1_64/', batch_size=512, hidden_size=100, embed_dim=50, epoch=100, lr=0.001, lr_dc=0.1, lr_dc_step=80, test=False, topk=20, valid_portion=0.1)
# Loading data...
# --------------------------------------------------
# Dataset info:
# Number of sessions: 332873
# --------------------------------------------------
# --------------------------------------------------
# Dataset info:
# Number of sessions: 36986
# --------------------------------------------------
# --------------------------------------------------
# Dataset info:
# Number of sessions: 55898
# --------------------------------------------------
# ...

# %%
# !python main.py --test --dataset_path /kaggle/working/Neural-Attentive-Session-Based-Recommendation-PyTorch/datasets/yoochoose1_64/
# Out:
# Namespace(dataset_path='/kaggle/working/Neural-Attentive-Session-Based-Recommendation-PyTorch/datasets/yoochoose1_64/', batch_size=512, hidden_size=100, embed_dim=50, epoch=100, lr=0.001, lr_dc=0.1, lr_dc_step=80, test=True, topk=20, valid_portion=0.1)
# Loading data...
# --------------------------------------------------
# Dataset info:
# Number of sessions: 332873
# --------------------------------------------------
# --------------------------------------------------
# Dataset info:
# Number of sessions: 36986
# --------------------------------------------------
# --------------------------------------------------
# Dataset info:
# Number of sessions: 55898
# --------------------------------------------------
# 100%|█████████████████████████████████████████| 110/110 [00:01<00:00, 64.53it/s]
# Test: Recall@20: 0.6884, MRR@20: 0.2952
