# %%
import pandas as pd
from datetime import datetime

# %%
temp = pd.read_csv('/content/data.txt')

# %%
temp = temp.drop(temp.columns[1], axis=1)

# %%
temp.columns = ['sessionId', 'timestamp', 'itemId', 'category']

# %%
temp['timestamp'] = temp['timestamp'].apply(lambda x: datetime.utcfromtimestamp(unix_timestamp).strftime("%Y-%m-%dT%H:%M:%S.%fZ")[:-4] + "Z")

# %%
temp
# Out:
#     sessionId                 timestamp  itemId  category
# 0           0  2009-02-13T23:30:29.000Z   19422         2
# 1           0  2009-02-13T23:30:29.000Z   19423         2
# 2           0  2009-02-13T23:30:29.000Z   19424         2
# 3           0  2009-02-13T23:30:29.000Z   19425         2
# 4           0  2009-02-13T23:30:29.000Z   19426         2
# 5           0  2009-02-13T23:30:29.000Z   19427         2
# 6           0  2009-02-13T23:30:29.000Z   19428         2
# 7           0  2009-02-13T23:30:29.000Z   19429         2
# 8           0  2009-02-13T23:30:29.000Z   19445         2
# 9           1  2009-02-13T23:30:29.000Z   13211         3
# 10          2  2009-02-13T23:30:29.000Z    1321         4

# %%
temp.to_csv('./datasets/yoochoose/yoochoose-clicks.dat', index=False)

# %%
# !python src/preprocessing.py --dataset yoochoose
# Out:
# INFO:root:Running preprocessing for yoochoose dataset
# INFO:root:Read 11 events from datasets/yoochoose/yoochoose-clicks.dat
# INFO:root:Creating sessions...
# 100% 11/11 [00:00<00:00, 1361.87it/s]
# INFO:root:Created 3 sessions for yoochoose
# INFO:root:Filtering sessions...
# 100% 3/3 [00:00<00:00, 71089.90it/s]
# 100% 1/1 [00:00<00:00, 27413.75it/s]
# 100% 1/1 [00:00<00:00, 34100.03it/s]
# INFO:root:Remaining sessions after filtering: 0
# INFO:root:Splitting sessions into train and test...
# Traceback (most recent call last):
#   File "/content/Session-Based-Models/src/preprocessing.py", line 284, in <module>
#     main()
#   File "/content/Session-Based-Models/src/preprocessing.py", line 270, in main
#     run_preprocessing(yoochoose_conf, data_dir)
#   File "/content/Session-Based-Models/src/preprocessing.py", line 167, in run_preprocessing
#     train_sessions, test_sessions = train_test_split(sessions, dataset_name, config["split_seconds"], config["split_idx"])
# ...
